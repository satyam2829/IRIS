# %% [markdown]
# <h1> <center> Exploratory Data Analysis <center> </h1>

# %% [markdown]
# <ol>
#     <li> Histogram </li>
#     <li> Box Plot </li>
#     <li> Scatter Plot </li>
#     <li> Pair Plot </li>
#     <li> Correlation matrix </li>
# </ol>

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the data

# %%
data = pd.read_csv('iris.csv')

# %% [markdown]
# ### Top 5 rows

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### High Level Information about dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ### Statistics Information about dataset

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### Checking null values

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# <h3 style='color:red'> Observation: There are no missing values in the data.</h3>

# %% [markdown]
# ### Species Count

# %%
pd.DataFrame(data['Species'].value_counts())
# Out:
#                  Species
# Iris-versicolor       50
# Iris-setosa           50
# Iris-virginica        50

# %% [markdown]
# <h3 style='color:red'> Observation: The dataset is balanced. All the species are distributed equally.</h3>

# %% [markdown]
# ### Countplot: Species

# %%
sns.countplot(data['Species'])
plt.title('Iris Species Count')
plt.show()

# %% [markdown]
# # 1. Univariate Analysis

# %% [markdown]
# ## 1.1. Histogram

# %%
sepal_length = data['SepalLengthCm']
sepal_width = data['SepalWidthCm']
petal_length = data['PetalLengthCm']
petal_width = data['PetalWidthCm']

# %% [markdown]
# ### 1.1.1. Sepal Length

# %%
plt.hist(sepal_length, edgecolor='black', bins=10)
plt.xlabel('Sepal Length')
plt.ylabel('Count')
plt.title('Histogram - Sepal Length')
plt.show()

# %% [markdown]
# ### 1.1.2. Sepal Width

# %%
plt.hist(sepal_width, edgecolor='black', bins=10)
plt.xlabel('Sepal Width')
plt.ylabel('Count')
plt.title('Histogram - Sepal Width')
plt.show()

# %% [markdown]
# ### 1.1.3. Petal Length

# %%
plt.hist(petal_length, edgecolor='black', bins=10)
plt.xlabel('Petal Length')
plt.ylabel('Count')
plt.title('Histogram - Petal Length')
plt.show()

# %% [markdown]
# ### 1.1.4. Petal Width

# %%
plt.hist(petal_width, edgecolor='black', bins=10)
plt.xlabel('Petal width')
plt.ylabel('Count')
plt.title('Histogram - Petal Width')
plt.show()

# %% [markdown]
# ## 1.2. Boxplot

# %% [markdown]
# ### 1.2.1. Sepal Length

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=data)
plt.show()

# %% [markdown]
# ### 1.2.2. Sepal Width

# %%
sns.boxplot(x='Species', y='SepalWidthCm', data=data)
plt.show()

# %% [markdown]
# ### 1.2.3. Petal Length

# %%
sns.boxplot(x='Species', y='PetalLengthCm', data=data)
plt.show()

# %% [markdown]
# ### 1.2.4. Petal Width

# %%
sns.boxplot(x='Species',y='PetalWidthCm',data=data)
plt.show()

# %% [markdown]
# # 2.Bivariate Analysis

# %% [markdown]
# ## 2.1. Scatter Plot

# %% [markdown]
# ### 2.1.1. Sepal Length vs Sepal Width

# %%
sns.scatterplot(sepal_length, sepal_width, hue=data['Species'])
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %% [markdown]
# ### 2.1.2. Petal Length vs Petal Width

# %%
sns.scatterplot(petal_length, petal_width, hue=data['Species'])
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.title('Sepal Length vs Sepal Width')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 2.2. Pair Plot

# %%
data = data.drop(['Id'], axis=1)

# %%
sns.pairplot(data, hue='Species')
plt.show()

# %% [markdown]
# # 3. Correlation

# %%
df_corr = data.drop(['Species'],axis=1)

# %%
cor_mat = df_corr.corr()

# %%
sns.heatmap(cor_mat, annot=True, cmap='summer')
plt.show()
